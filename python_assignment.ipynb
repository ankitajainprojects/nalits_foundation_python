# %%
print(f"Hello, World!")
# Out:
# Hello, World!

# %%
a=27
b=15
print(f"Sum: {a+b}")
# Out:
# Sum: 42

# %%
width= 5.0
height= 10.0
print(f"Area of rectangle: {width*height}")
# Out:
# Area of rectangle: 50.0
